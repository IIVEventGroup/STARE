# %% [markdown]
# **Prepare environment:**

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import os
import sys
import matplotlib.pyplot as plt
from pathlib import Path

plt.rcParams['figure.figsize'] = [14, 8]

work_dir = Path.cwd().parent.parent.parent
# print(work_dir)
sys.path.append(str(work_dir))
# print(sys.path)

from lib.test.analysis.plot_results import plot_results, print_results, print_per_sequence_results
from lib.test.evaluation import get_dataset, trackerlist

# %% [markdown]
# **For stream-based latency-aware evaluation with OSTrack+P:**

# %%
dataset_name = 'esot500s'
dataset = get_dataset(dataset_name)

trackers = []

trackers.extend(
    trackerlist(
        name='ostrack',
        parameter_name='pred_esot500_4step',
        dataset_name=dataset_name,
        run_ids=None,
        display_name='OSTrack_P',
    )
)

trackers.extend(
    trackerlist(
        name='ostrack',
        parameter_name='pred_esot500_4step',
        dataset_name=dataset_name,
        run_ids=66,
        display_name='OSTrack_P_C'
    )
)

# %%
# Sim - Realtime - OSTrack+Pred - L - s101 - 2ms

stream_setting_id = 101

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
    stream_id=stream_setting_id,
)

# %%
# Sim - Realtime - OSTrack+Pred - L - s102 - 20ms

stream_setting_id = 102

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
    stream_id=stream_setting_id,
)

# %%
# Sim - Realtime - OSTrack+Pred - L - s103 - 50ms

stream_setting_id = 103

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
    stream_id=stream_setting_id,
)

# %%
# Sim - Realtime - OSTrack+Pred - L - s104 - 100ms

stream_setting_id = 104

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
    stream_id=stream_setting_id,
)

# %%
# Sim - Realtime - OSTrack+Pred - L - s105 - 150ms

stream_setting_id = 105

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
    stream_id=stream_setting_id,
)

# %%
# Sim - Realtime - OSTrack+Pred - L - s106 - 200ms

stream_setting_id = 106

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
    stream_id=stream_setting_id,
)
