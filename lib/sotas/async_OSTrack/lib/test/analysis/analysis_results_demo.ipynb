# %% [markdown]
# **Prepare environment:**

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import os
import sys
import matplotlib.pyplot as plt
from pathlib import Path

plt.rcParams['figure.figsize'] = [14, 8]

work_dir = Path.cwd().parent.parent.parent
# print(work_dir)
sys.path.append(str(work_dir))
# print(sys.path)

from lib.test.analysis.plot_results import plot_results, print_results, print_per_sequence_results
from lib.test.evaluation import get_dataset, trackerlist

# %% [markdown]
# **For frame-based evaluation demo:**

# %%
# Frame-based evaluation - SOTAs - OSTrack

dataset_name = 'esot_20_50'
trackers = []

trackers.extend(trackerlist(name='ostrack',
                            parameter_name='esot500mix',
                            dataset_name=dataset_name,
                            run_ids=None,
                            display_name='ostrack'))

dataset = get_dataset(dataset_name)
print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
)

# %% [markdown]
# **For stream-based latency-aware evaluation demo:**

# %%
# Realtime - SOTAs - OSTrack

dataset_name = 'esot500s'
trackers = []

trackers.extend(trackerlist(name='async_ostrack',
                            parameter_name='esot500_async_full_100',
                            dataset_name=dataset_name,
                            run_ids=None,
                            display_name='async_ostrack'))

stream_setting_id = 102

dataset = get_dataset(dataset_name)
print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
    stream_id=stream_setting_id,
)

# %%
# Realtime - SOTAs - OSTrack

dataset_name = 'esot500s'
trackers = []

trackers.extend(trackerlist(name='async_ostrack',
                            parameter_name='esot500_async_full_100',
                            dataset_name=dataset_name,
                            run_ids=69,
                            display_name='async_ostrack'))

stream_setting_id = 102

dataset = get_dataset(dataset_name)
print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
    stream_id=stream_setting_id,
)

# %%
# Realtime - SOTAs - OSTrack

dataset_name = 'esot500s'
trackers = []

trackers.extend(trackerlist(name='async_ostrack',
                            parameter_name='esot500_async_freezing_100_w_pretrain',
                            dataset_name=dataset_name,
                            run_ids=110,
                            display_name='async_ostrack'))

stream_setting_id = 102

dataset = get_dataset(dataset_name)
print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
    stream_id=stream_setting_id,
)

# %%
# Realtime - SOTAs - OSTrack

dataset_name = 'esot500s'
trackers = []

trackers.extend(trackerlist(name='async_ostrack',
                            parameter_name='esot500_20_async_freezing_150_w_pretrain',
                            dataset_name=dataset_name,
                            run_ids=60,
                            display_name='async_ostrack'))

stream_setting_id = 102

dataset = get_dataset(dataset_name)
print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
    stream_id=stream_setting_id,
)

# %%
# Realtime - SOTAs - OSTrack

dataset_name = 'esot500s'
trackers = []

trackers.extend(trackerlist(name='async_ostrack',
                            parameter_name='esot500_mix_async_freezing_150_w_pretrain_wo_ce',
                            dataset_name=dataset_name,
                            run_ids=70,
                            display_name='async_ostrack'))

stream_setting_id = 102

dataset = get_dataset(dataset_name)
print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
    stream_id=stream_setting_id,
)

# %%
# Realtime - SOTAs - OSTrack

dataset_name = 'esot500s'
trackers = []

trackers.extend(trackerlist(name='async_ostrack',
                            parameter_name='esot500_mix_async_freezing_150_w_pretrain',
                            dataset_name=dataset_name,
                            run_ids=79,
                            display_name='async_ostrack'))

stream_setting_id = 106

dataset = get_dataset(dataset_name)
print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
    stream_id=stream_setting_id,
)

# %%
# Realtime - SOTAs - OSTrack

dataset_name = 'esot500s'
trackers = []

trackers.extend(trackerlist(name='async_ostrack',
                            parameter_name='esot500_mix_async_freezing_150_w_pretrain',
                            dataset_name=dataset_name,
                            run_ids=70,
                            display_name='async_ostrack'))

stream_setting_id = 102

dataset = get_dataset(dataset_name)
print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
    stream_id=stream_setting_id,
)

print_per_sequence_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    stream_id=stream_setting_id,
)

# %%
# Realtime - SOTAs - OSTrack + C

dataset_name = 'esot500s'
trackers = []

trackers.extend(trackerlist(name='ostrack',
                            parameter_name='esot500_baseline',
                            dataset_name=dataset_name,
                            run_ids=66,
                            display_name='ostrack_c'))

stream_setting_id = 14

dataset = get_dataset(dataset_name)
print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
    stream_id=stream_setting_id,
)
